# %%
import json

# %%
filename = "eq_data_1_day_m1.json"

with open(filename) as f:
    all_eq_data = json.load(f)
    #print(all_eq_data)
    
readable_file = "readable_eq_data.json"
with open(readable_file, 'w') as f:
    json.dump(all_eq_data, f, indent = 4)

# %%
type(all_eq_data)
# Out:
# dict

# %%
all_eq_data
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1550361461000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_day.geojson',
#   'title': 'USGS Magnitude 1.0+ Earthquakes, Past Day',
#   'status': 200,
#   'api': '1.7.0',
#   'count': 158},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 0.96,
#     'place': '8km NE of Aguanga, CA',
#     'time': 1550360775470,
#     'updated': 1550360993593,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532978',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532978.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 14,
#     'net': 'ci',
#     'code': '37532978',
#     'ids': ',ci37532978,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 32,
#     'dmin': 0.02648,
#     'rms': 0.15,
#     'gap': 37,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 8km NE of Aguanga, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.7941667, 33.4863333, 3.22]},
#    'id': 'ci37532978'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '11km NNE of North Nenana, Alaska',
#     'time': 1550358909272,
#     'updated': 1550359211283,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192641ikq',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192641ikq.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ak',
#     'code': '0192641ikq',
#     'ids': ',ak0192641ikq,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.94,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 11km NNE of North Nenana, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.9865, 64.6673, 0]},
#    'id': 'ak0192641ikq'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '69km NNW of Ayna, Peru',
#     'time': 1550358621670,
#     'updated': 1550360269040,
#     'tz': -300,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jizi',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jizi.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '2000jizi',
#     'ids': ',us2000jizi,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 2.553,
#     'rms': 1.08,
#     'gap': 98,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 69km NNW of Ayna, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-74.2343, -12.1025, 10]},
#    'id': 'us2000jizi'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.6,
#     'place': '126km SSE of Cold Bay, Alaska',
#     'time': 1550358590770,
#     'updated': 1550359431040,
#     'tz': -660,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jizh',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jizh.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 199,
#     'net': 'us',
#     'code': '2000jizh',
#     'ids': ',us2000jizh,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 1.194,
#     'rms': 0.82,
#     'gap': 177,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.6 - 126km SSE of Cold Bay, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-161.6801, 54.2232, 46.66]},
#    'id': 'us2000jizh'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.1,
#     'place': '21km NNW of Tehachapi, CA',
#     'time': 1550358390290,
#     'updated': 1550359037950,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532962',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532962.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 68,
#     'net': 'ci',
#     'code': '37532962',
#     'ids': ',ci37532962,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.09256,
#     'rms': 0.18,
#     'gap': 87,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 21km NNW of Tehachapi, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.5316667, 35.3098333, 3.88]},
#    'id': 'ci37532962'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '57km SSW of Kaktovik, Alaska',
#     'time': 1550356508630,
#     'updated': 1550358075284,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019263kdhw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019263kdhw.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.1,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 246,
#     'net': 'ak',
#     'code': '019263kdhw',
#     'ids': ',at00pn1iql,ak019263kdhw,us2000jiz7,',
#     'sources': ',at,ak,us,',
#     'types': ',geoserve,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.98,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 57km SSW of Kaktovik, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-144.1283, 69.5346, 10]},
#    'id': 'ak019263kdhw'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.06,
#     'place': '8km SW of Anza, CA',
#     'time': 1550356217940,
#     'updated': 1550356445857,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532938',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532938.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 17,
#     'net': 'ci',
#     'code': '37532938',
#     'ids': ',ci37532938,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 33,
#     'dmin': 0.0477,
#     'rms': 0.22,
#     'gap': 42,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 8km SW of Anza, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.7433333, 33.5148333, 4.24]},
#    'id': 'ci37532938'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.3,
#     'place': '65km ESE of Old Iliamna, Alaska',
#     'time': 1550356119954,
#     'updated': 1550356451996,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019263ixnc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019263ixnc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 81,
#     'net': 'ak',
#     'code': '019263ixnc',
#     'ids': ',ak019263ixnc,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.54,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 65km ESE of Old Iliamna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-153.7845, 59.6106, 137.1]},
#    'id': 'ak019263ixnc'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': 'Southwest Indian Ridge',
#     'time': 1550356117390,
#     'updated': 1550357706040,
#     'tz': 240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jiz9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jiz9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '2000jiz9',
#     'ids': ',us2000jiz9,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 10.08,
#     'rms': 0.51,
#     'gap': 86,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - Southwest Indian Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [59.3991, -30.7399, 10]},
#    'id': 'us2000jiz9'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '52km ENE of Beatty, Nevada',
#     'time': 1550354788310,
#     'updated': 1550354861660,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00677991',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00677991.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'nn',
#     'code': '00677991',
#     'ids': ',nn00677991,',
#     'sources': ',nn,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.168,
#     'rms': 0.19,
#     'gap': 169.67,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 52km ENE of Beatty, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2045, 37.0572, 0.9]},
#    'id': 'nn00677991'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.29,
#     'place': '30km SSW of Fillmore, Utah',
#     'time': 1550354730730,
#     'updated': 1550360491889,
#     'tz': -420,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60312977',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60312977.geojson',
#     'felt': 3,
#     'cdi': 3.4,
#     'mmi': 3.65,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 168,
#     'net': 'uu',
#     'code': '60312977',
#     'ids': ',uu60312977,us2000jiyw,',
#     'sources': ',uu,us,',
#     'types': ',dyfi,geoserve,origin,phase-data,shakemap,',
#     'nst': 27,
#     'dmin': 0.1334,
#     'rms': 0.2,
#     'gap': 46,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 30km SSW of Fillmore, Utah'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-112.4931667, 38.7381667, 8.01]},
#    'id': 'uu60312977'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '32km W of Ester, Alaska',
#     'time': 1550353904919,
#     'updated': 1550354174292,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192632fwt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192632fwt.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '0192632fwt',
#     'ids': ',ak0192632fwt,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.48,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 32km W of Ester, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.7061, 64.8513, 16.8]},
#    'id': 'ak0192632fwt'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '177km ENE of Petropavlovsk-Kamchatskiy, Russia',
#     'time': 1550353764260,
#     'updated': 1550354855040,
#     'tz': 660,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jiyt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jiyt.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '2000jiyt',
#     'ids': ',us2000jiyt,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 1.604,
#     'rms': 1.37,
#     'gap': 136,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 177km ENE of Petropavlovsk-Kamchatskiy, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [161.1651, 53.566, 35]},
#    'id': 'us2000jiyt'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.08,
#     'place': '14km W of Old Faithful Geyser, Wyoming',
#     'time': 1550352170860,
#     'updated': 1550359053040,
#     'tz': -420,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60312957',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60312957.geojson',
#     'felt': 5,
#     'cdi': 3.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 148,
#     'net': 'uu',
#     'code': '60312957',
#     'ids': ',uu60312957,us2000jiyg,',
#     'sources': ',uu,us,',
#     'types': ',dyfi,geoserve,origin,phase-data,',
#     'nst': 25,
#     'dmin': 0.1259,
#     'rms': 0.23,
#     'gap': 73,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 14km W of Old Faithful Geyser, Wyoming'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-111.0103333, 44.4668333, 8.23]},
#    'id': 'uu60312957'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.2,
#     'place': '94km SSE of Old Iliamna, Alaska',
#     'time': 1550351607103,
#     'updated': 1550351987018,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019262u9cv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019262u9cv.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 74,
#     'net': 'ak',
#     'code': '019262u9cv',
#     'ids': ',ak019262u9cv,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.84,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 94km SSE of Old Iliamna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-154.4451, 58.9382, 123.8]},
#    'id': 'ak019262u9cv'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '15km SSW of Big Lake, Alaska',
#     'time': 1550351403169,
#     'updated': 1550351575208,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019262tkbg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019262tkbg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '019262tkbg',
#     'ids': ',ak019262tkbg,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.44,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 15km SSW of Big Lake, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.0831, 61.3962, 37.6]},
#    'id': 'ak019262tkbg'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '5km S of Big Lake, Alaska',
#     'time': 1550349953503,
#     'updated': 1550350667652,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019262fqnq',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019262fqnq.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 40,
#     'net': 'ak',
#     'code': '019262fqnq',
#     'ids': ',ak019262fqnq,',
#     'sources': ',ak,',
#     'types': ',dyfi,geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.36,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 5km S of Big Lake, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.9686, 61.4763, 44]},
#    'id': 'ak019262fqnq'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.29,
#     'place': '14km NE of Yucaipa, CA',
#     'time': 1550349411920,
#     'updated': 1550349633853,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532850',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532850.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ci',
#     'code': '37532850',
#     'ids': ',ci37532850,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 32,
#     'dmin': 0.1218,
#     'rms': 0.26,
#     'gap': 62,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 14km NE of Yucaipa, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.9223333, 34.1115, 13.29]},
#    'id': 'ci37532850'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.1,
#     'place': '47km SSW of Tok, Alaska',
#     'time': 1550348323948,
#     'updated': 1550348605513,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192629xkv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192629xkv.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 68,
#     'net': 'ak',
#     'code': '0192629xkv',
#     'ids': ',ak0192629xkv,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.83,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 47km SSW of Tok, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-143.4818, 62.9725, 2.8]},
#    'id': 'ak0192629xkv'},
#   {'type': 'Feature',
#    'properties': {'mag': 2,
#     'place': '13km NW of Anchorage, Alaska',
#     'time': 1550346021860,
#     'updated': 1550346388098,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019261t60w',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019261t60w.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'ak',
#     'code': '019261t60w',
#     'ids': ',ak019261t60w,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.62,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 13km NW of Anchorage, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.0881, 61.2929, 36.1]},
#    'id': 'ak019261t60w'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '4km S of Volcano, Hawaii',
#     'time': 1550345622640,
#     'updated': 1550345822850,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70813861',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv70813861.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'hv',
#     'code': '70813861',
#     'ids': ',hv70813861,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 36,
#     'dmin': 0.01279,
#     'rms': 0.13,
#     'gap': 42,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 4km S of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2371674, 19.3859997, 27.86]},
#    'id': 'hv70813861'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.08,
#     'place': '3km SSE of Belden, CA',
#     'time': 1550343863990,
#     'updated': 1550355989734,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73143016',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73143016.geojson',
#     'felt': 7,
#     'cdi': 4.3,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 149,
#     'net': 'nc',
#     'code': '73143016',
#     'ids': ',nc73143016,nn00677974,',
#     'sources': ',nc,nn,',
#     'types': ',dyfi,focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 34,
#     'dmin': 0.2794,
#     'rms': 0.49,
#     'gap': 94,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 3km SSE of Belden, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.2385025, 39.9780006, -1.16]},
#    'id': 'nc73143016'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '27km NE of Cantwell, Alaska',
#     'time': 1550342846267,
#     'updated': 1550343016730,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01926198s2',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01926198s2.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '01926198s2',
#     'ids': ',ak01926198s2,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.29,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 27km NE of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.6093, 63.5896, 6.7]},
#    'id': 'ak01926198s2'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.33,
#     'place': '1km NNW of Indios, Puerto Rico',
#     'time': 1550342601300,
#     'updated': 1550346701370,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047021',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047021.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 84,
#     'net': 'pr',
#     'code': '2019047021',
#     'ids': ',pr2019047021,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 15,
#     'dmin': 0.0604,
#     'rms': 0.59,
#     'gap': 145,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 1km NNW of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.8275, 18.0063, 4]},
#    'id': 'pr2019047021'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '28km SSE of Redoubt Volcano, Alaska',
#     'time': 1550342595469,
#     'updated': 1550342855846,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192618d1k',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192618d1k.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '0192618d1k',
#     'ids': ',ak0192618d1k,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.86,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 28km SSE of Redoubt Volcano, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.6213, 60.2343, 97.2]},
#    'id': 'ak0192618d1k'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.11,
#     'place': '66km NNE of Punta Cana, Dominican Republic',
#     'time': 1550341735330,
#     'updated': 1550351853708,
#     'tz': -300,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047022',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047022.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 149,
#     'net': 'pr',
#     'code': '2019047022',
#     'ids': ',pr2019047022,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.6508,
#     'rms': 0.23,
#     'gap': 190,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 66km NNE of Punta Cana, Dominican Republic'},
#    'geometry': {'type': 'Point', 'coordinates': [-68.0565, 19.0778, 54]},
#    'id': 'pr2019047022'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '21km WNW of Kalifornsky, Alaska',
#     'time': 1550341652122,
#     'updated': 1550346639040,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192614yvt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192614yvt.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'ak',
#     'code': '0192614yvt',
#     'ids': ',ak0192614yvt,us2000jiwy,',
#     'sources': ',ak,us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.71,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 21km WNW of Kalifornsky, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.6356, 60.5105, 54.6]},
#    'id': 'ak0192614yvt'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.3,
#     'place': '31km WNW of Willow, Alaska',
#     'time': 1550341153777,
#     'updated': 1550341540049,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01926137ru',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01926137ru.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 81,
#     'net': 'ak',
#     'code': '01926137ru',
#     'ids': ',ak01926137ru,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.53,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 31km WNW of Willow, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.5944, 61.8365, 61.4]},
#    'id': 'ak01926137ru'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '13km SSW of Big Lake, Alaska',
#     'time': 1550340578992,
#     'updated': 1550340936906,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01926114jb',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01926114jb.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': '01926114jb',
#     'ids': ',ak01926114jb,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.43,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 13km SSW of Big Lake, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.0873, 61.4155, 36.2]},
#    'id': 'ak01926114jb'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.89,
#     'place': '26km NNW of Tehachapi, CA',
#     'time': 1550338823460,
#     'updated': 1550339467370,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532730',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532730.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 55,
#     'net': 'ci',
#     'code': '37532730',
#     'ids': ',ci37532730,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,',
#     'nst': 23,
#     'dmin': 0.1244,
#     'rms': 0.17,
#     'gap': 94,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 26km NNW of Tehachapi, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.5568333, 35.3471667, 3.42]},
#    'id': 'ci37532730'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.05,
#     'place': '5km WSW of Palm Springs, CA',
#     'time': 1550338229750,
#     'updated': 1550338456303,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532722',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532722.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 17,
#     'net': 'ci',
#     'code': '37532722',
#     'ids': ',ci37532722,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 25,
#     'dmin': 0.03289,
#     'rms': 0.15,
#     'gap': 69,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 5km WSW of Palm Springs, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.5841667, 33.807, 13.95]},
#    'id': 'ci37532722'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.16,
#     'place': '18km N of Borrego Springs, CA',
#     'time': 1550337597000,
#     'updated': 1550337819468,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532714',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532714.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 21,
#     'net': 'ci',
#     'code': '37532714',
#     'ids': ',ci37532714,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.1204,
#     'rms': 0.22,
#     'gap': 141,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 18km N of Borrego Springs, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.3608333, 33.4156667, 12.78]},
#    'id': 'ci37532714'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '13km N of Meadow Lakes, Alaska',
#     'time': 1550336211482,
#     'updated': 1550336452614,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192604d14',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192604d14.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '0192604d14',
#     'ids': ',ak0192604d14,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.82,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 13km N of Meadow Lakes, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.5674, 61.7445, 48]},
#    'id': 'ak0192604d14'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '19km N of Fishhook, Alaska',
#     'time': 1550335852667,
#     'updated': 1550336010532,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01926032r5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01926032r5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '01926032r5',
#     'ids': ',ak01926032r5,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.83,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 19km N of Fishhook, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.2188, 61.9231, 18.5]},
#    'id': 'ak01926032r5'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.68,
#     'place': '5km S of Brawley, CA',
#     'time': 1550335717270,
#     'updated': 1550335945383,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532706',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532706.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 43,
#     'net': 'ci',
#     'code': '37532706',
#     'ids': ',ci37532706,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.0358,
#     'rms': 0.22,
#     'gap': 94,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 5km S of Brawley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.54, 32.9328333, 5.17]},
#    'id': 'ci37532706'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.29,
#     'place': '6km NW of The Geysers, CA',
#     'time': 1550335579220,
#     'updated': 1550338924271,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73143011',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73143011.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'nc',
#     'code': '73143011',
#     'ids': ',nc73143011,',
#     'sources': ',nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.009384,
#     'rms': 0.04,
#     'gap': 52,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 6km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8098297, 38.8139992, 2.59]},
#    'id': 'nc73143011'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '26km WNW of Valdez, Alaska',
#     'time': 1550335516304,
#     'updated': 1550335729380,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192601xda',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192601xda.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '0192601xda',
#     'ids': ',ak0192601xda,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.7,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 26km WNW of Valdez, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-146.8137, 61.2207, 34.4]},
#    'id': 'ak0192601xda'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '24km WSW of Cohoe, Alaska',
#     'time': 1550335458902,
#     'updated': 1550335628768,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192601puq',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192601puq.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '0192601puq',
#     'ids': ',ak0192601puq,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.44,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 24km WSW of Cohoe, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.7243, 60.2853, 56.9]},
#    'id': 'ak0192601puq'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.87,
#     'place': '5km E of La Parguera, Puerto Rico',
#     'time': 1550335374170,
#     'updated': 1550351770508,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047020',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047020.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 54,
#     'net': 'pr',
#     'code': '2019047020',
#     'ids': ',pr2019047020,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 5,
#     'dmin': 0.1165,
#     'rms': 0.26,
#     'gap': 206,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 5km E of La Parguera, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.0001, 17.9666, 12]},
#    'id': 'pr2019047020'},
#   {'type': 'Feature',
#    'properties': {'mag': 1,
#     'place': '0km ENE of The Geysers, CA',
#     'time': 1550335127660,
#     'updated': 1550337364128,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73143006',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73143006.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'nc',
#     'code': '73143006',
#     'ids': ',nc73143006,',
#     'sources': ',nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 7,
#     'dmin': 0.0113,
#     'rms': 0.02,
#     'gap': 103,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 0km ENE of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7545013, 38.777832, 0.39]},
#    'id': 'nc73143006'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '66km NNE of Talkeetna, Alaska',
#     'time': 1550332956455,
#     'updated': 1550333301382,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925zsr4t',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925zsr4t.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '01925zsr4t',
#     'ids': ',ak01925zsr4t,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.43,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 66km NNE of Talkeetna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.517, 62.8545, 93.8]},
#    'id': 'ak01925zsr4t'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '54km W of Anchor Point, Alaska',
#     'time': 1550332597798,
#     'updated': 1550332949612,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925ziwe5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925ziwe5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '01925ziwe5',
#     'ids': ',ak01925ziwe5,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.67,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 54km W of Anchor Point, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.7856, 59.7132, 83.1]},
#    'id': 'ak01925ziwe5'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.34,
#     'place': '18km ESE of Kernville, CA',
#     'time': 1550332103280,
#     'updated': 1550333641548,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532666',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532666.geojson',
#     'felt': 1,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 28,
#     'net': 'ci',
#     'code': '37532666',
#     'ids': ',ci37532666,',
#     'sources': ',ci,',
#     'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.01886,
#     'rms': 0.15,
#     'gap': 100,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 18km ESE of Kernville, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.2513333, 35.6781667, 8.71]},
#    'id': 'ci37532666'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': '102km N of Redoubt Volcano, Alaska',
#     'time': 1550330154060,
#     'updated': 1550330371544,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925za572',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925za572.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'ak',
#     'code': '01925za572',
#     'ids': ',ak01925za572,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.38,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 102km N of Redoubt Volcano, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-153.0445, 61.3963, 4.9]},
#    'id': 'ak01925za572'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '111km NW of Talkeetna, Alaska',
#     'time': 1550329235511,
#     'updated': 1550329518695,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925z6w0v',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925z6w0v.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '01925z6w0v',
#     'ids': ',ak01925z6w0v,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.7,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 111km NW of Talkeetna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.5818, 63.066, 2.6]},
#    'id': 'ak01925z6w0v'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '12km SSW of Pecos, Texas',
#     'time': 1550329183380,
#     'updated': 1550337693040,
#     'tz': -360,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jivj',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jivj.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'us',
#     'code': '2000jivj',
#     'ids': ',us2000jivj,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.293,
#     'rms': 0.77,
#     'gap': 62,
#     'magType': 'mb_lg',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 12km SSW of Pecos, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-103.5309, 31.3115, 5]},
#    'id': 'us2000jivj'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.19,
#     'place': '26km ENE of Coso Junction, CA',
#     'time': 1550329173240,
#     'updated': 1550329385892,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532650',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532650.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ci',
#     'code': '37532650',
#     'ids': ',ci37532650,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.1176,
#     'rms': 0.12,
#     'gap': 110,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 26km ENE of Coso Junction, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.671, 36.1148333, 0.79]},
#    'id': 'ci37532650'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.46,
#     'place': '76km N of Tierras Nuevas Poniente, Puerto Rico',
#     'time': 1550329104830,
#     'updated': 1550338157120,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047019',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047019.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 93,
#     'net': 'pr',
#     'code': '2019047019',
#     'ids': ',pr2019047019,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.6792,
#     'rms': 0.27,
#     'gap': 298,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 76km N of Tierras Nuevas Poniente, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.5226, 19.1563, 11]},
#    'id': 'pr2019047019'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '10km SW of Big Lake, Alaska',
#     'time': 1550328614130,
#     'updated': 1550328775914,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925yw4kl',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925yw4kl.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '01925yw4kl',
#     'ids': ',ak01925yw4kl,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.43,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 10km SW of Big Lake, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.0767, 61.4484, 30.2]},
#    'id': 'ak01925yw4kl'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '109km W of Cantwell, Alaska',
#     'time': 1550326010117,
#     'updated': 1550326238333,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925ymrul',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925ymrul.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '01925ymrul',
#     'ids': ',ak01925ymrul,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.69,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 109km W of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.1402, 63.3234, 9.5]},
#    'id': 'ak01925ymrul'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.4,
#     'place': '113km W of Cantwell, Alaska',
#     'time': 1550325835215,
#     'updated': 1550326137592,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925ym51h',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925ym51h.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 89,
#     'net': 'ak',
#     'code': '01925ym51h',
#     'ids': ',ak01925ym51h,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.98,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 113km W of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.2276, 63.388, 4.3]},
#    'id': 'ak01925ym51h'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.64,
#     'place': '15km E of Seven Trees, CA',
#     'time': 1550325554920,
#     'updated': 1550335743977,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73142991',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73142991.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 41,
#     'net': 'nc',
#     'code': '73142991',
#     'ids': ',nc73142991,',
#     'sources': ',nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 10,
#     'dmin': 0.04996,
#     'rms': 0.04,
#     'gap': 174,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 15km E of Seven Trees, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.675499, 37.3089981, 5.79]},
#    'id': 'nc73142991'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '75km W of Mentone, Texas',
#     'time': 1550325537980,
#     'updated': 1550326509040,
#     'tz': -360,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jiv9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jiv9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'us',
#     'code': '2000jiv9',
#     'ids': ',us2000jiv9,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.43,
#     'rms': 0.84,
#     'gap': 70,
#     'magType': 'mb_lg',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 75km W of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.39, 31.6283, 5]},
#    'id': 'us2000jiv9'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.09,
#     'place': '8km NE of Aguanga, CA',
#     'time': 1550324671850,
#     'updated': 1550325348390,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532634',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532634.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'ci',
#     'code': '37532634',
#     'ids': ',ci37532634,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,',
#     'nst': 39,
#     'dmin': 0.02645,
#     'rms': 0.2,
#     'gap': 38,
#     'magType': 'ml',
#     'type': 'earthquake',
# ...
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '69km NW of Nikiski, Alaska',
#     'time': 1550284531757,
#     'updated': 1550284714885,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925rnqx9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925rnqx9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '01925rnqx9',
#     'ids': ',ak01925rnqx9,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.78,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 69km NW of Nikiski, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.22, 61.1183, 0.4]},
#    'id': 'ak01925rnqx9'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.91,
#     'place': '4km WSW of Volcano, Hawaii',
#     'time': 1550284131380,
#     'updated': 1550284489200,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70812656',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv70812656.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'hv',
#     'code': '70812656',
#     'ids': ',hv70812656,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.01139,
#     'rms': 0.17,
#     'gap': 46,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 4km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.272995, 19.413166, 0.41]},
#    'id': 'hv70812656'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '71km SSW of Kobuk, Alaska',
#     'time': 1550283448150,
#     'updated': 1550354537040,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jipg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jipg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'us',
#     'code': '2000jipg',
#     'ids': ',us2000jipg,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.169,
#     'rms': 0.94,
#     'gap': 52,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 71km SSW of Kobuk, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-157.2918, 66.29, 10]},
#    'id': 'us2000jipg'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '3km SSE of Big Lake, Alaska',
#     'time': 1550282521297,
#     'updated': 1550282748813,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925rgly9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925rgly9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '01925rgly9',
#     'ids': ',ak01925rgly9,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.61,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 3km SSE of Big Lake, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.9289, 61.493, 33]},
#    'id': 'ak01925rgly9'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '22km SSW of Lithakia, Greece',
#     'time': 1550282235550,
#     'updated': 1550316595902,
#     'tz': 120,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jinx',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jinx.geojson',
#     'felt': 2,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 272,
#     'net': 'us',
#     'code': '2000jinx',
#     'ids': ',us2000jinx,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 1.028,
#     'rms': 1.23,
#     'gap': 143,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 22km SSW of Lithakia, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [20.7165, 37.5408, 10]},
#    'id': 'us2000jinx'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.28,
#     'place': '51km NW of San Antonio, Puerto Rico',
#     'time': 1550282073560,
#     'updated': 1550284841040,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047000.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 166,
#     'net': 'pr',
#     'code': '2019047000',
#     'ids': ',pr2019047000,us2000jipc,',
#     'sources': ',pr,us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.398,
#     'rms': 0.45,
#     'gap': 284,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 51km NW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.4526, 18.7816, 9]},
#    'id': 'pr2019047000'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.2,
#     'place': '65km NNE of Redoubt Volcano, Alaska',
#     'time': 1550281301461,
#     'updated': 1550281693402,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925r3md0',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925r3md0.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 74,
#     'net': 'ak',
#     'code': '01925r3md0',
#     'ids': ',ak01925r3md0,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.38,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 65km NNE of Redoubt Volcano, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.3045, 61.0343, 107.8]},
#    'id': 'ak01925r3md0'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.16,
#     'place': '2km NNW of The Geysers, CA',
#     'time': 1550281013290,
#     'updated': 1550284385030,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73142836',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73142836.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 21,
#     'net': 'nc',
#     'code': '73142836',
#     'ids': ',nc73142836,',
#     'sources': ',nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.01768,
#     'rms': 0.02,
#     'gap': 76,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 2km NNW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7653351, 38.7921677, 1.72]},
#    'id': 'nc73142836'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '253km SE of Kodiak, Alaska',
#     'time': 1550280915213,
#     'updated': 1550281201571,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925r2c5r',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925r2c5r.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '01925r2c5r',
#     'ids': ',ak01925r2c5r,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.69,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 253km SE of Kodiak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.4308, 56.1936, 6.2]},
#    'id': 'ak01925r2c5r'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': '79km SSW of Bengkulu, Indonesia',
#     'time': 1550280431850,
#     'updated': 1550282712040,
#     'tz': 420,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jine',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jine.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '2000jine',
#     'ids': ',us2000jine,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.961,
#     'rms': 0.73,
#     'gap': 163,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - 79km SSW of Bengkulu, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [101.9982, -4.4716, 35]},
#    'id': 'us2000jine'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.32,
#     'place': '84km N of Loiza, Puerto Rico',
#     'time': 1550280281960,
#     'updated': 1550311023887,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047005',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047005.geojson',
#     'felt': 1,
#     'cdi': 4.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 170,
#     'net': 'pr',
#     'code': '2019047005',
#     'ids': ',pr2019047005,',
#     'sources': ',pr,',
#     'types': ',dyfi,geoserve,origin,phase-data,',
#     'nst': 3,
#     'dmin': 1.052,
#     'rms': 0.58,
#     'gap': 330,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 84km N of Loiza, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-65.7698, 19.1911, 124]},
#    'id': 'pr2019047005'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '81km S of Kaktovik, Alaska',
#     'time': 1550279570240,
#     'updated': 1550354319040,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jinc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jinc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'us',
#     'code': '2000jinc',
#     'ids': ',us2000jinc,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.224,
#     'rms': 0.79,
#     'gap': 99,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 81km S of Kaktovik, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-143.7027, 69.4029, 10]},
#    'id': 'us2000jinc'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.75,
#     'place': '5km WNW of Mayaguez, Puerto Rico',
#     'time': 1550279428370,
#     'updated': 1550296945040,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047004',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047004.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'pr',
#     'code': '2019047004',
#     'ids': ',pr2019047004,us2000jira,',
#     'sources': ',pr,us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.2259,
#     'rms': 0.13,
#     'gap': 213,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 5km WNW of Mayaguez, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.1808, 18.2208, 108]},
#    'id': 'pr2019047004'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.2,
#     'place': '91km N of Road Town, British Virgin Islands',
#     'time': 1550279048060,
#     'updated': 1550297378040,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047003',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047003.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 158,
#     'net': 'pr',
#     'code': '2019047003',
#     'ids': ',pr2019047003,us2000jir9,',
#     'sources': ',pr,us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 4,
#     'dmin': 1.5988,
#     'rms': 0.25,
#     'gap': 346,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 91km N of Road Town, British Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.6176, 19.1621, 100]},
#    'id': 'pr2019047003'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '13km S of Big Lake, Alaska',
#     'time': 1550277554751,
#     'updated': 1550277844310,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925qhp9v',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925qhp9v.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '01925qhp9v',
#     'ids': ',ak01925qhp9v,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.47,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 13km S of Big Lake, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.982, 61.4021, 43.3]},
#    'id': 'ak01925qhp9v'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '78km ENE of Cape Yakataga, Alaska',
#     'time': 1550277129093,
#     'updated': 1550277301411,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925qg6tp',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925qg6tp.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': '01925qg6tp',
#     'ids': ',ak01925qg6tp,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.35,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 78km ENE of Cape Yakataga, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-141.1985, 60.4072, 0.8]},
#    'id': 'ak01925qg6tp'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '21km NNE of Badger, Alaska',
#     'time': 1550276104117,
#     'updated': 1550276408063,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925qcj9v',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925qcj9v.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '01925qcj9v',
#     'ids': ',ak01925qcj9v,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.42,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 21km NNE of Badger, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.2898, 64.9632, 6.7]},
#    'id': 'ak01925qcj9v'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.96,
#     'place': '60km NNW of San Antonio, Puerto Rico',
#     'time': 1550275421070,
#     'updated': 1550294471469,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047002',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047002.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 135,
#     'net': 'pr',
#     'code': '2019047002',
#     'ids': ',pr2019047002,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 4,
#     'dmin': 0.571,
#     'rms': 0.25,
#     'gap': 333,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 60km NNW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.2263, 19.0268, 7]},
#    'id': 'pr2019047002'}],
#  'bbox': [-176.7088, -30.7399, -1.16, 164.5151, 69.5346, 249.4]}

# %%
all_eq_dicts = all_eq_data['features']
all_eq_dicts[0]
all_eq_dicts[157]
len(all_eq_dicts)
# Out:
# 158

# %%
all_eq_dicts
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 0.96,
#    'place': '8km NE of Aguanga, CA',
#    'time': 1550360775470,
#    'updated': 1550360993593,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532978',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532978.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 14,
#    'net': 'ci',
#    'code': '37532978',
#    'ids': ',ci37532978,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,',
#    'nst': 32,
#    'dmin': 0.02648,
#    'rms': 0.15,
#    'gap': 37,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 8km NE of Aguanga, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.7941667, 33.4863333, 3.22]},
#   'id': 'ci37532978'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '11km NNE of North Nenana, Alaska',
#    'time': 1550358909272,
#    'updated': 1550359211283,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192641ikq',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192641ikq.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'ak',
#    'code': '0192641ikq',
#    'ids': ',ak0192641ikq,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.94,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 11km NNE of North Nenana, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-148.9865, 64.6673, 0]},
#   'id': 'ak0192641ikq'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.3,
#    'place': '69km NNW of Ayna, Peru',
#    'time': 1550358621670,
#    'updated': 1550360269040,
#    'tz': -300,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jizi',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jizi.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 284,
#    'net': 'us',
#    'code': '2000jizi',
#    'ids': ',us2000jizi,',
#    'sources': ',us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 2.553,
#    'rms': 1.08,
#    'gap': 98,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.3 - 69km NNW of Ayna, Peru'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.2343, -12.1025, 10]},
#   'id': 'us2000jizi'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.6,
#    'place': '126km SSE of Cold Bay, Alaska',
#    'time': 1550358590770,
#    'updated': 1550359431040,
#    'tz': -660,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jizh',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jizh.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 199,
#    'net': 'us',
#    'code': '2000jizh',
#    'ids': ',us2000jizh,',
#    'sources': ',us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 1.194,
#    'rms': 0.82,
#    'gap': 177,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 3.6 - 126km SSE of Cold Bay, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-161.6801, 54.2232, 46.66]},
#   'id': 'us2000jizh'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.1,
#    'place': '21km NNW of Tehachapi, CA',
#    'time': 1550358390290,
#    'updated': 1550359037950,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532962',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532962.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 68,
#    'net': 'ci',
#    'code': '37532962',
#    'ids': ',ci37532962,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,',
#    'nst': 27,
#    'dmin': 0.09256,
#    'rms': 0.18,
#    'gap': 87,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 21km NNW of Tehachapi, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.5316667, 35.3098333, 3.88]},
#   'id': 'ci37532962'},
#  {'type': 'Feature',
#   'properties': {'mag': 4,
#    'place': '57km SSW of Kaktovik, Alaska',
#    'time': 1550356508630,
#    'updated': 1550358075284,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019263kdhw',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019263kdhw.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': 4.1,
#    'alert': 'green',
#    'status': 'reviewed',
#    'tsunami': 1,
#    'sig': 246,
#    'net': 'ak',
#    'code': '019263kdhw',
#    'ids': ',at00pn1iql,ak019263kdhw,us2000jiz7,',
#    'sources': ',at,ak,us,',
#    'types': ',geoserve,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.98,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 4.0 - 57km SSW of Kaktovik, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-144.1283, 69.5346, 10]},
#   'id': 'ak019263kdhw'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.06,
#    'place': '8km SW of Anza, CA',
#    'time': 1550356217940,
#    'updated': 1550356445857,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532938',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532938.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 17,
#    'net': 'ci',
#    'code': '37532938',
#    'ids': ',ci37532938,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,',
#    'nst': 33,
#    'dmin': 0.0477,
#    'rms': 0.22,
#    'gap': 42,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 8km SW of Anza, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.7433333, 33.5148333, 4.24]},
#   'id': 'ci37532938'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.3,
#    'place': '65km ESE of Old Iliamna, Alaska',
#    'time': 1550356119954,
#    'updated': 1550356451996,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019263ixnc',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019263ixnc.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 81,
#    'net': 'ak',
#    'code': '019263ixnc',
#    'ids': ',ak019263ixnc,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.54,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 65km ESE of Old Iliamna, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-153.7845, 59.6106, 137.1]},
#   'id': 'ak019263ixnc'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.9,
#    'place': 'Southwest Indian Ridge',
#    'time': 1550356117390,
#    'updated': 1550357706040,
#    'tz': 240,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jiz9',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jiz9.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 369,
#    'net': 'us',
#    'code': '2000jiz9',
#    'ids': ',us2000jiz9,',
#    'sources': ',us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 10.08,
#    'rms': 0.51,
#    'gap': 86,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.9 - Southwest Indian Ridge'},
#   'geometry': {'type': 'Point', 'coordinates': [59.3991, -30.7399, 10]},
#   'id': 'us2000jiz9'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '52km ENE of Beatty, Nevada',
#    'time': 1550354788310,
#    'updated': 1550354861660,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00677991',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00677991.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'nn',
#    'code': '00677991',
#    'ids': ',nn00677991,',
#    'sources': ',nn,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 11,
#    'dmin': 0.168,
#    'rms': 0.19,
#    'gap': 169.67,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 52km ENE of Beatty, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.2045, 37.0572, 0.9]},
#   'id': 'nn00677991'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.29,
#    'place': '30km SSW of Fillmore, Utah',
#    'time': 1550354730730,
#    'updated': 1550360491889,
#    'tz': -420,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60312977',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60312977.geojson',
#    'felt': 3,
#    'cdi': 3.4,
#    'mmi': 3.65,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 168,
#    'net': 'uu',
#    'code': '60312977',
#    'ids': ',uu60312977,us2000jiyw,',
#    'sources': ',uu,us,',
#    'types': ',dyfi,geoserve,origin,phase-data,shakemap,',
#    'nst': 27,
#    'dmin': 0.1334,
#    'rms': 0.2,
#    'gap': 46,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.3 - 30km SSW of Fillmore, Utah'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-112.4931667, 38.7381667, 8.01]},
#   'id': 'uu60312977'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '32km W of Ester, Alaska',
#    'time': 1550353904919,
#    'updated': 1550354174292,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192632fwt',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192632fwt.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ak',
#    'code': '0192632fwt',
#    'ids': ',ak0192632fwt,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.48,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 32km W of Ester, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-148.7061, 64.8513, 16.8]},
#   'id': 'ak0192632fwt'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.5,
#    'place': '177km ENE of Petropavlovsk-Kamchatskiy, Russia',
#    'time': 1550353764260,
#    'updated': 1550354855040,
#    'tz': 660,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jiyt',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jiyt.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 312,
#    'net': 'us',
#    'code': '2000jiyt',
#    'ids': ',us2000jiyt,',
#    'sources': ',us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 1.604,
#    'rms': 1.37,
#    'gap': 136,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.5 - 177km ENE of Petropavlovsk-Kamchatskiy, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [161.1651, 53.566, 35]},
#   'id': 'us2000jiyt'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.08,
#    'place': '14km W of Old Faithful Geyser, Wyoming',
#    'time': 1550352170860,
#    'updated': 1550359053040,
#    'tz': -420,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60312957',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60312957.geojson',
#    'felt': 5,
#    'cdi': 3.2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 148,
#    'net': 'uu',
#    'code': '60312957',
#    'ids': ',uu60312957,us2000jiyg,',
#    'sources': ',uu,us,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': 25,
#    'dmin': 0.1259,
#    'rms': 0.23,
#    'gap': 73,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.1 - 14km W of Old Faithful Geyser, Wyoming'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-111.0103333, 44.4668333, 8.23]},
#   'id': 'uu60312957'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.2,
#    'place': '94km SSE of Old Iliamna, Alaska',
#    'time': 1550351607103,
#    'updated': 1550351987018,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019262u9cv',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019262u9cv.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 74,
#    'net': 'ak',
#    'code': '019262u9cv',
#    'ids': ',ak019262u9cv,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.84,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.2 - 94km SSE of Old Iliamna, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-154.4451, 58.9382, 123.8]},
#   'id': 'ak019262u9cv'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '15km SSW of Big Lake, Alaska',
#    'time': 1550351403169,
#    'updated': 1550351575208,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019262tkbg',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019262tkbg.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ak',
#    'code': '019262tkbg',
#    'ids': ',ak019262tkbg,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.44,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 15km SSW of Big Lake, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.0831, 61.3962, 37.6]},
#   'id': 'ak019262tkbg'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '5km S of Big Lake, Alaska',
#    'time': 1550349953503,
#    'updated': 1550350667652,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019262fqnq',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019262fqnq.geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 40,
#    'net': 'ak',
#    'code': '019262fqnq',
#    'ids': ',ak019262fqnq,',
#    'sources': ',ak,',
#    'types': ',dyfi,geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.36,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 5km S of Big Lake, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.9686, 61.4763, 44]},
#   'id': 'ak019262fqnq'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.29,
#    'place': '14km NE of Yucaipa, CA',
#    'time': 1550349411920,
#    'updated': 1550349633853,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532850',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532850.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ci',
#    'code': '37532850',
#    'ids': ',ci37532850,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,',
#    'nst': 32,
#    'dmin': 0.1218,
#    'rms': 0.26,
#    'gap': 62,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 14km NE of Yucaipa, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.9223333, 34.1115, 13.29]},
#   'id': 'ci37532850'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.1,
#    'place': '47km SSW of Tok, Alaska',
#    'time': 1550348323948,
#    'updated': 1550348605513,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192629xkv',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192629xkv.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 68,
#    'net': 'ak',
#    'code': '0192629xkv',
#    'ids': ',ak0192629xkv,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.83,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 47km SSW of Tok, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-143.4818, 62.9725, 2.8]},
#   'id': 'ak0192629xkv'},
#  {'type': 'Feature',
#   'properties': {'mag': 2,
#    'place': '13km NW of Anchorage, Alaska',
#    'time': 1550346021860,
#    'updated': 1550346388098,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019261t60w',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019261t60w.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 62,
#    'net': 'ak',
#    'code': '019261t60w',
#    'ids': ',ak019261t60w,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.62,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 13km NW of Anchorage, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.0881, 61.2929, 36.1]},
#   'id': 'ak019261t60w'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '4km S of Volcano, Hawaii',
#    'time': 1550345622640,
#    'updated': 1550345822850,
#    'tz': -600,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70813861',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv70813861.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'hv',
#    'code': '70813861',
#    'ids': ',hv70813861,',
#    'sources': ',hv,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 36,
#    'dmin': 0.01279,
#    'rms': 0.13,
#    'gap': 42,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 4km S of Volcano, Hawaii'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-155.2371674, 19.3859997, 27.86]},
#   'id': 'hv70813861'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.08,
#    'place': '3km SSE of Belden, CA',
#    'time': 1550343863990,
#    'updated': 1550355989734,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73143016',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73143016.geojson',
#    'felt': 7,
#    'cdi': 4.3,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 149,
#    'net': 'nc',
#    'code': '73143016',
#    'ids': ',nc73143016,nn00677974,',
#    'sources': ',nc,nn,',
#    'types': ',dyfi,focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 34,
#    'dmin': 0.2794,
#    'rms': 0.49,
#    'gap': 94,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.1 - 3km SSE of Belden, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.2385025, 39.9780006, -1.16]},
#   'id': 'nc73143016'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '27km NE of Cantwell, Alaska',
#    'time': 1550342846267,
#    'updated': 1550343016730,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01926198s2',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01926198s2.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '01926198s2',
#    'ids': ',ak01926198s2,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.29,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 27km NE of Cantwell, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-148.6093, 63.5896, 6.7]},
#   'id': 'ak01926198s2'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.33,
#    'place': '1km NNW of Indios, Puerto Rico',
#    'time': 1550342601300,
#    'updated': 1550346701370,
#    'tz': -240,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047021',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047021.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 84,
#    'net': 'pr',
#    'code': '2019047021',
#    'ids': ',pr2019047021,',
#    'sources': ',pr,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 15,
#    'dmin': 0.0604,
#    'rms': 0.59,
#    'gap': 145,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 1km NNW of Indios, Puerto Rico'},
#   'geometry': {'type': 'Point', 'coordinates': [-66.8275, 18.0063, 4]},
#   'id': 'pr2019047021'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '28km SSE of Redoubt Volcano, Alaska',
#    'time': 1550342595469,
#    'updated': 1550342855846,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192618d1k',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192618d1k.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0192618d1k',
#    'ids': ',ak0192618d1k,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.86,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 28km SSE of Redoubt Volcano, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.6213, 60.2343, 97.2]},
#   'id': 'ak0192618d1k'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.11,
#    'place': '66km NNE of Punta Cana, Dominican Republic',
#    'time': 1550341735330,
#    'updated': 1550351853708,
#    'tz': -300,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047022',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047022.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 149,
#    'net': 'pr',
#    'code': '2019047022',
#    'ids': ',pr2019047022,',
#    'sources': ',pr,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.6508,
#    'rms': 0.23,
#    'gap': 190,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 3.1 - 66km NNE of Punta Cana, Dominican Republic'},
#   'geometry': {'type': 'Point', 'coordinates': [-68.0565, 19.0778, 54]},
#   'id': 'pr2019047022'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.9,
#    'place': '21km WNW of Kalifornsky, Alaska',
#    'time': 1550341652122,
#    'updated': 1550346639040,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192614yvt',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192614yvt.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 129,
#    'net': 'ak',
#    'code': '0192614yvt',
#    'ids': ',ak0192614yvt,us2000jiwy,',
#    'sources': ',ak,us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.71,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 21km WNW of Kalifornsky, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.6356, 60.5105, 54.6]},
#   'id': 'ak0192614yvt'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.3,
#    'place': '31km WNW of Willow, Alaska',
#    'time': 1550341153777,
#    'updated': 1550341540049,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01926137ru',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01926137ru.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 81,
#    'net': 'ak',
#    'code': '01926137ru',
#    'ids': ',ak01926137ru,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.53,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 31km WNW of Willow, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.5944, 61.8365, 61.4]},
#   'id': 'ak01926137ru'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.5,
#    'place': '13km SSW of Big Lake, Alaska',
#    'time': 1550340578992,
#    'updated': 1550340936906,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01926114jb',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01926114jb.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'ak',
#    'code': '01926114jb',
#    'ids': ',ak01926114jb,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.43,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 13km SSW of Big Lake, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.0873, 61.4155, 36.2]},
#   'id': 'ak01926114jb'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.89,
#    'place': '26km NNW of Tehachapi, CA',
#    'time': 1550338823460,
#    'updated': 1550339467370,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532730',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532730.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 55,
#    'net': 'ci',
#    'code': '37532730',
#    'ids': ',ci37532730,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,',
#    'nst': 23,
#    'dmin': 0.1244,
#    'rms': 0.17,
#    'gap': 94,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 26km NNW of Tehachapi, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.5568333, 35.3471667, 3.42]},
#   'id': 'ci37532730'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.05,
#    'place': '5km WSW of Palm Springs, CA',
#    'time': 1550338229750,
#    'updated': 1550338456303,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532722',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532722.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 17,
#    'net': 'ci',
#    'code': '37532722',
#    'ids': ',ci37532722,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,',
#    'nst': 25,
#    'dmin': 0.03289,
#    'rms': 0.15,
#    'gap': 69,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 5km WSW of Palm Springs, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.5841667, 33.807, 13.95]},
#   'id': 'ci37532722'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.16,
#    'place': '18km N of Borrego Springs, CA',
#    'time': 1550337597000,
#    'updated': 1550337819468,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532714',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532714.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 21,
#    'net': 'ci',
#    'code': '37532714',
#    'ids': ',ci37532714,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,',
#    'nst': 27,
#    'dmin': 0.1204,
#    'rms': 0.22,
#    'gap': 141,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 18km N of Borrego Springs, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.3608333, 33.4156667, 12.78]},
#   'id': 'ci37532714'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '13km N of Meadow Lakes, Alaska',
#    'time': 1550336211482,
#    'updated': 1550336452614,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192604d14',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192604d14.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0192604d14',
#    'ids': ',ak0192604d14,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.82,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 13km N of Meadow Lakes, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.5674, 61.7445, 48]},
#   'id': 'ak0192604d14'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '19km N of Fishhook, Alaska',
#    'time': 1550335852667,
#    'updated': 1550336010532,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01926032r5',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01926032r5.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ak',
#    'code': '01926032r5',
#    'ids': ',ak01926032r5,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.83,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 19km N of Fishhook, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.2188, 61.9231, 18.5]},
#   'id': 'ak01926032r5'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.68,
#    'place': '5km S of Brawley, CA',
#    'time': 1550335717270,
#    'updated': 1550335945383,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532706',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532706.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 43,
#    'net': 'ci',
#    'code': '37532706',
#    'ids': ',ci37532706,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,',
#    'nst': 18,
#    'dmin': 0.0358,
#    'rms': 0.22,
#    'gap': 94,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 5km S of Brawley, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.54, 32.9328333, 5.17]},
#   'id': 'ci37532706'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.29,
#    'place': '6km NW of The Geysers, CA',
#    'time': 1550335579220,
#    'updated': 1550338924271,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73143011',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73143011.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'nc',
#    'code': '73143011',
#    'ids': ',nc73143011,',
#    'sources': ',nc,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 19,
#    'dmin': 0.009384,
#    'rms': 0.04,
#    'gap': 52,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 6km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.8098297, 38.8139992, 2.59]},
#   'id': 'nc73143011'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '26km WNW of Valdez, Alaska',
#    'time': 1550335516304,
#    'updated': 1550335729380,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192601xda',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192601xda.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0192601xda',
#    'ids': ',ak0192601xda,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.7,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 26km WNW of Valdez, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-146.8137, 61.2207, 34.4]},
#   'id': 'ak0192601xda'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '24km WSW of Cohoe, Alaska',
#    'time': 1550335458902,
#    'updated': 1550335628768,
#    'tz': -600,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0192601puq',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0192601puq.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ak',
#    'code': '0192601puq',
#    'ids': ',ak0192601puq,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.44,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 24km WSW of Cohoe, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.7243, 60.2853, 56.9]},
#   'id': 'ak0192601puq'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.87,
#    'place': '5km E of La Parguera, Puerto Rico',
#    'time': 1550335374170,
#    'updated': 1550351770508,
#    'tz': -240,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047020',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047020.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 54,
#    'net': 'pr',
#    'code': '2019047020',
#    'ids': ',pr2019047020,',
#    'sources': ',pr,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.1165,
#    'rms': 0.26,
#    'gap': 206,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 5km E of La Parguera, Puerto Rico'},
#   'geometry': {'type': 'Point', 'coordinates': [-67.0001, 17.9666, 12]},
#   'id': 'pr2019047020'},
#  {'type': 'Feature',
#   'properties': {'mag': 1,
#    'place': '0km ENE of The Geysers, CA',
#    'time': 1550335127660,
#    'updated': 1550337364128,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73143006',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73143006.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 15,
#    'net': 'nc',
#    'code': '73143006',
#    'ids': ',nc73143006,',
#    'sources': ',nc,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 7,
#    'dmin': 0.0113,
#    'rms': 0.02,
#    'gap': 103,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 0km ENE of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.7545013, 38.777832, 0.39]},
#   'id': 'nc73143006'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '66km NNE of Talkeetna, Alaska',
#    'time': 1550332956455,
#    'updated': 1550333301382,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925zsr4t',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925zsr4t.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'ak',
#    'code': '01925zsr4t',
#    'ids': ',ak01925zsr4t,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.43,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 66km NNE of Talkeetna, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.517, 62.8545, 93.8]},
#   'id': 'ak01925zsr4t'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.7,
#    'place': '54km W of Anchor Point, Alaska',
#    'time': 1550332597798,
#    'updated': 1550332949612,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925ziwe5',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925ziwe5.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'ak',
#    'code': '01925ziwe5',
#    'ids': ',ak01925ziwe5,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.67,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 54km W of Anchor Point, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.7856, 59.7132, 83.1]},
#   'id': 'ak01925ziwe5'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.34,
#    'place': '18km ESE of Kernville, CA',
#    'time': 1550332103280,
#    'updated': 1550333641548,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532666',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532666.geojson',
#    'felt': 1,
#    'cdi': 2.2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 28,
#    'net': 'ci',
#    'code': '37532666',
#    'ids': ',ci37532666,',
#    'sources': ',ci,',
#    'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,',
#    'nst': 12,
#    'dmin': 0.01886,
#    'rms': 0.15,
#    'gap': 100,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 18km ESE of Kernville, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.2513333, 35.6781667, 8.71]},
#   'id': 'ci37532666'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.9,
#    'place': '102km N of Redoubt Volcano, Alaska',
#    'time': 1550330154060,
#    'updated': 1550330371544,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925za572',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925za572.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 56,
#    'net': 'ak',
#    'code': '01925za572',
#    'ids': ',ak01925za572,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 1.38,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 102km N of Redoubt Volcano, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-153.0445, 61.3963, 4.9]},
#   'id': 'ak01925za572'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.7,
#    'place': '111km NW of Talkeetna, Alaska',
#    'time': 1550329235511,
#    'updated': 1550329518695,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925z6w0v',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925z6w0v.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'ak',
#    'code': '01925z6w0v',
#    'ids': ',ak01925z6w0v,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.7,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 111km NW of Talkeetna, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.5818, 63.066, 2.6]},
#   'id': 'ak01925z6w0v'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.6,
#    'place': '12km SSW of Pecos, Texas',
#    'time': 1550329183380,
#    'updated': 1550337693040,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jivj',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jivj.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 104,
#    'net': 'us',
#    'code': '2000jivj',
#    'ids': ',us2000jivj,',
#    'sources': ',us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.293,
#    'rms': 0.77,
#    'gap': 62,
#    'magType': 'mb_lg',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 12km SSW of Pecos, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-103.5309, 31.3115, 5]},
#   'id': 'us2000jivj'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.19,
#    'place': '26km ENE of Coso Junction, CA',
#    'time': 1550329173240,
#    'updated': 1550329385892,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532650',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532650.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'ci',
#    'code': '37532650',
#    'ids': ',ci37532650,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,',
#    'nst': 10,
#    'dmin': 0.1176,
#    'rms': 0.12,
#    'gap': 110,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 26km ENE of Coso Junction, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.671, 36.1148333, 0.79]},
#   'id': 'ci37532650'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.46,
#    'place': '76km N of Tierras Nuevas Poniente, Puerto Rico',
#    'time': 1550329104830,
#    'updated': 1550338157120,
#    'tz': -240,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047019',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047019.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 93,
#    'net': 'pr',
#    'code': '2019047019',
#    'ids': ',pr2019047019,',
#    'sources': ',pr,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.6792,
#    'rms': 0.27,
#    'gap': 298,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 76km N of Tierras Nuevas Poniente, Puerto Rico'},
#   'geometry': {'type': 'Point', 'coordinates': [-66.5226, 19.1563, 11]},
#   'id': 'pr2019047019'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '10km SW of Big Lake, Alaska',
#    'time': 1550328614130,
#    'updated': 1550328775914,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925yw4kl',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925yw4kl.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '01925yw4kl',
#    'ids': ',ak01925yw4kl,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.43,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 10km SW of Big Lake, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.0767, 61.4484, 30.2]},
#   'id': 'ak01925yw4kl'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '109km W of Cantwell, Alaska',
#    'time': 1550326010117,
#    'updated': 1550326238333,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925ymrul',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925ymrul.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ak',
#    'code': '01925ymrul',
#    'ids': ',ak01925ymrul,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.69,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 109km W of Cantwell, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.1402, 63.3234, 9.5]},
#   'id': 'ak01925ymrul'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.4,
#    'place': '113km W of Cantwell, Alaska',
#    'time': 1550325835215,
#    'updated': 1550326137592,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925ym51h',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925ym51h.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 89,
#    'net': 'ak',
#    'code': '01925ym51h',
#    'ids': ',ak01925ym51h,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.98,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.4 - 113km W of Cantwell, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.2276, 63.388, 4.3]},
#   'id': 'ak01925ym51h'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.64,
#    'place': '15km E of Seven Trees, CA',
#    'time': 1550325554920,
#    'updated': 1550335743977,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73142991',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73142991.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 41,
#    'net': 'nc',
#    'code': '73142991',
#    'ids': ',nc73142991,',
#    'sources': ',nc,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 10,
#    'dmin': 0.04996,
#    'rms': 0.04,
#    'gap': 174,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 15km E of Seven Trees, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.675499, 37.3089981, 5.79]},
#   'id': 'nc73142991'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.9,
#    'place': '75km W of Mentone, Texas',
#    'time': 1550325537980,
#    'updated': 1550326509040,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jiv9',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jiv9.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 129,
#    'net': 'us',
#    'code': '2000jiv9',
#    'ids': ',us2000jiv9,',
#    'sources': ',us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.43,
#    'rms': 0.84,
#    'gap': 70,
#    'magType': 'mb_lg',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 75km W of Mentone, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.39, 31.6283, 5]},
#   'id': 'us2000jiv9'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.09,
#    'place': '8km NE of Aguanga, CA',
#    'time': 1550324671850,
#    'updated': 1550325348390,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37532634',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci37532634.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 18,
#    'net': 'ci',
#    'code': '37532634',
#    'ids': ',ci37532634,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,',
#    'nst': 39,
#    'dmin': 0.02645,
#    'rms': 0.2,
#    'gap': 38,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 8km NE of Aguanga, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.7905, 33.4871667, 5.66]},
#   'id': 'ci37532634'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.58,
#    'place': '6km W of Cobb, CA',
#    'time': 1550323734330,
#    'updated': 1550331003503,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73142976',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73142976.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 38,
#    'net': 'nc',
#    'code': '73142976',
#    'ids': ',nc73142976,',
#    'sources': ',nc,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 19,
#    'dmin': 0.00775,
#    'rms': 0.03,
#    'gap': 44,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 6km W of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.7925034, 38.8308334, 1.39]},
#   'id': 'nc73142976'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '13km S of Big Lake, Alaska',
#    'time': 1550323494456,
#    'updated': 1550323679620,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925y57gl',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925y57gl.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ak',
#    'code': '01925y57gl',
#    'ids': ',ak01925y57gl,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.57,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 13km S of Big Lake, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.9197, 61.4028, 33]},
#   'id': 'ak01925y57gl'},
#  {'type': 'Feature',
# ...
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 125,
#    'net': 'pr',
#    'code': '2019047001',
#    'ids': ',pr2019047001,us2000jipq,',
#    'sources': ',pr,us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.8801,
#    'rms': 0.31,
#    'gap': 295,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 77km N of San Juan, Puerto Rico'},
#   'geometry': {'type': 'Point', 'coordinates': [-66.0208, 19.1953, 20]},
#   'id': 'pr2019047001'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '69km NW of Nikiski, Alaska',
#    'time': 1550284531757,
#    'updated': 1550284714885,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925rnqx9',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925rnqx9.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ak',
#    'code': '01925rnqx9',
#    'ids': ',ak01925rnqx9,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.78,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 69km NW of Nikiski, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.22, 61.1183, 0.4]},
#   'id': 'ak01925rnqx9'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.91,
#    'place': '4km WSW of Volcano, Hawaii',
#    'time': 1550284131380,
#    'updated': 1550284489200,
#    'tz': -600,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70812656',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv70812656.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 56,
#    'net': 'hv',
#    'code': '70812656',
#    'ids': ',hv70812656,',
#    'sources': ',hv,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 19,
#    'dmin': 0.01139,
#    'rms': 0.17,
#    'gap': 46,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 4km WSW of Volcano, Hawaii'},
#   'geometry': {'type': 'Point', 'coordinates': [-155.272995, 19.413166, 0.41]},
#   'id': 'hv70812656'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.6,
#    'place': '71km SSW of Kobuk, Alaska',
#    'time': 1550283448150,
#    'updated': 1550354537040,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jipg',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jipg.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 104,
#    'net': 'us',
#    'code': '2000jipg',
#    'ids': ',us2000jipg,',
#    'sources': ',us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.169,
#    'rms': 0.94,
#    'gap': 52,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 71km SSW of Kobuk, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-157.2918, 66.29, 10]},
#   'id': 'us2000jipg'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.7,
#    'place': '3km SSE of Big Lake, Alaska',
#    'time': 1550282521297,
#    'updated': 1550282748813,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925rgly9',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925rgly9.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'ak',
#    'code': '01925rgly9',
#    'ids': ',ak01925rgly9,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.61,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 3km SSE of Big Lake, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.9289, 61.493, 33]},
#   'id': 'ak01925rgly9'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.2,
#    'place': '22km SSW of Lithakia, Greece',
#    'time': 1550282235550,
#    'updated': 1550316595902,
#    'tz': 120,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jinx',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jinx.geojson',
#    'felt': 2,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 272,
#    'net': 'us',
#    'code': '2000jinx',
#    'ids': ',us2000jinx,',
#    'sources': ',us,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 1.028,
#    'rms': 1.23,
#    'gap': 143,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.2 - 22km SSW of Lithakia, Greece'},
#   'geometry': {'type': 'Point', 'coordinates': [20.7165, 37.5408, 10]},
#   'id': 'us2000jinx'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.28,
#    'place': '51km NW of San Antonio, Puerto Rico',
#    'time': 1550282073560,
#    'updated': 1550284841040,
#    'tz': -240,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047000',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047000.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 166,
#    'net': 'pr',
#    'code': '2019047000',
#    'ids': ',pr2019047000,us2000jipc,',
#    'sources': ',pr,us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.398,
#    'rms': 0.45,
#    'gap': 284,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 3.3 - 51km NW of San Antonio, Puerto Rico'},
#   'geometry': {'type': 'Point', 'coordinates': [-67.4526, 18.7816, 9]},
#   'id': 'pr2019047000'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.2,
#    'place': '65km NNE of Redoubt Volcano, Alaska',
#    'time': 1550281301461,
#    'updated': 1550281693402,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925r3md0',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925r3md0.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 74,
#    'net': 'ak',
#    'code': '01925r3md0',
#    'ids': ',ak01925r3md0,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.38,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.2 - 65km NNE of Redoubt Volcano, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.3045, 61.0343, 107.8]},
#   'id': 'ak01925r3md0'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.16,
#    'place': '2km NNW of The Geysers, CA',
#    'time': 1550281013290,
#    'updated': 1550284385030,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73142836',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73142836.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 21,
#    'net': 'nc',
#    'code': '73142836',
#    'ids': ',nc73142836,',
#    'sources': ',nc,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 14,
#    'dmin': 0.01768,
#    'rms': 0.02,
#    'gap': 76,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 2km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.7653351, 38.7921677, 1.72]},
#   'id': 'nc73142836'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.5,
#    'place': '253km SE of Kodiak, Alaska',
#    'time': 1550280915213,
#    'updated': 1550281201571,
#    'tz': -600,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925r2c5r',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925r2c5r.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 96,
#    'net': 'ak',
#    'code': '01925r2c5r',
#    'ids': ',ak01925r2c5r,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.69,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 253km SE of Kodiak, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.4308, 56.1936, 6.2]},
#   'id': 'ak01925r2c5r'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.7,
#    'place': '79km SSW of Bengkulu, Indonesia',
#    'time': 1550280431850,
#    'updated': 1550282712040,
#    'tz': 420,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jine',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jine.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 340,
#    'net': 'us',
#    'code': '2000jine',
#    'ids': ',us2000jine,',
#    'sources': ',us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.961,
#    'rms': 0.73,
#    'gap': 163,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.7 - 79km SSW of Bengkulu, Indonesia'},
#   'geometry': {'type': 'Point', 'coordinates': [101.9982, -4.4716, 35]},
#   'id': 'us2000jine'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.32,
#    'place': '84km N of Loiza, Puerto Rico',
#    'time': 1550280281960,
#    'updated': 1550311023887,
#    'tz': -240,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047005',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047005.geojson',
#    'felt': 1,
#    'cdi': 4.1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 170,
#    'net': 'pr',
#    'code': '2019047005',
#    'ids': ',pr2019047005,',
#    'sources': ',pr,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': 3,
#    'dmin': 1.052,
#    'rms': 0.58,
#    'gap': 330,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 3.3 - 84km N of Loiza, Puerto Rico'},
#   'geometry': {'type': 'Point', 'coordinates': [-65.7698, 19.1911, 124]},
#   'id': 'pr2019047005'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.5,
#    'place': '81km S of Kaktovik, Alaska',
#    'time': 1550279570240,
#    'updated': 1550354319040,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jinc',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jinc.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 96,
#    'net': 'us',
#    'code': '2000jinc',
#    'ids': ',us2000jinc,',
#    'sources': ',us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.224,
#    'rms': 0.79,
#    'gap': 99,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 81km S of Kaktovik, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-143.7027, 69.4029, 10]},
#   'id': 'us2000jinc'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.75,
#    'place': '5km WNW of Mayaguez, Puerto Rico',
#    'time': 1550279428370,
#    'updated': 1550296945040,
#    'tz': -240,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047004',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047004.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 116,
#    'net': 'pr',
#    'code': '2019047004',
#    'ids': ',pr2019047004,us2000jira,',
#    'sources': ',pr,us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.2259,
#    'rms': 0.13,
#    'gap': 213,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 5km WNW of Mayaguez, Puerto Rico'},
#   'geometry': {'type': 'Point', 'coordinates': [-67.1808, 18.2208, 108]},
#   'id': 'pr2019047004'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.2,
#    'place': '91km N of Road Town, British Virgin Islands',
#    'time': 1550279048060,
#    'updated': 1550297378040,
#    'tz': -240,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047003',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047003.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 158,
#    'net': 'pr',
#    'code': '2019047003',
#    'ids': ',pr2019047003,us2000jir9,',
#    'sources': ',pr,us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 4,
#    'dmin': 1.5988,
#    'rms': 0.25,
#    'gap': 346,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 3.2 - 91km N of Road Town, British Virgin Islands'},
#   'geometry': {'type': 'Point', 'coordinates': [-64.6176, 19.1621, 100]},
#   'id': 'pr2019047003'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '13km S of Big Lake, Alaska',
#    'time': 1550277554751,
#    'updated': 1550277844310,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925qhp9v',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925qhp9v.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ak',
#    'code': '01925qhp9v',
#    'ids': ',ak01925qhp9v,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.47,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 13km S of Big Lake, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.982, 61.4021, 43.3]},
#   'id': 'ak01925qhp9v'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.5,
#    'place': '78km ENE of Cape Yakataga, Alaska',
#    'time': 1550277129093,
#    'updated': 1550277301411,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925qg6tp',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925qg6tp.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'ak',
#    'code': '01925qg6tp',
#    'ids': ',ak01925qg6tp,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.35,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 78km ENE of Cape Yakataga, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-141.1985, 60.4072, 0.8]},
#   'id': 'ak01925qg6tp'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '21km NNE of Badger, Alaska',
#    'time': 1550276104117,
#    'updated': 1550276408063,
#    'tz': -540,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01925qcj9v',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak01925qcj9v.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ak',
#    'code': '01925qcj9v',
#    'ids': ',ak01925qcj9v,',
#    'sources': ',ak,',
#    'types': ',geoserve,origin,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.42,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 21km NNE of Badger, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-147.2898, 64.9632, 6.7]},
#   'id': 'ak01925qcj9v'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.96,
#    'place': '60km NNW of San Antonio, Puerto Rico',
#    'time': 1550275421070,
#    'updated': 1550294471469,
#    'tz': -240,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019047002',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019047002.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 135,
#    'net': 'pr',
#    'code': '2019047002',
#    'ids': ',pr2019047002,',
#    'sources': ',pr,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.571,
#    'rms': 0.25,
#    'gap': 333,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 3.0 - 60km NNW of San Antonio, Puerto Rico'},
#   'geometry': {'type': 'Point', 'coordinates': [-67.2263, 19.0268, 7]},
#   'id': 'pr2019047002'}]

# %%
all_eq_dicts[0]['properties']['mag']
# Out:
# 0.96

# %%
mags = []

for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    mags.append(mag)

print(mags[:10])
# Out:
# [0.96, 1.2, 4.3, 3.6, 2.1, 4, 1.06, 2.3, 4.9, 1.8]

# %%
all_eq_dicts[0]['geometry']['coordinates'][:2]
# Out:
# [-116.7941667, 33.4863333]

# %%
lats = []
lons = []

for eq_dict in all_eq_dicts:
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    
    lons.append(lon)
    lats.append(lat)
print(lons[:5])
print(lats[:5])
# Out:
# [-116.7941667, -148.9865, -74.2343, -161.6801, -118.5316667]
# [33.4863333, 64.6673, -12.1025, 54.2232, 35.3098333]

# %%
from plotly.graph_objs import Scattergeo, Layout
from plotly import offline


data = [Scattergeo(lon=lons, lat=lats)]
my_layout = Layout(title='Global Earthquakes')

fig = {'data':data, 'layout':my_layout}
offline.plot(fig, filename='global_earthquakes.html')
# Out:
# 'global_earthquakes.html'
